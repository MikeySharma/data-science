# %%
data_cancer <- read.csv('data.csv')

# %%
head(data_cancer)
# Out:
#   id       diagnosis radius_mean texture_mean perimeter_mean area_mean
# 1   842302 M         17.99       10.38        122.80         1001.0
# 2   842517 M         20.57       17.77        132.90         1326.0
# 3 84300903 M         19.69       21.25        130.00         1203.0
# 4 84348301 M         11.42       20.38         77.58          386.1
# 5 84358402 M         20.29       14.34        135.10         1297.0
# 6   843786 M         12.45       15.70         82.57          477.1
#   smoothness_mean compactness_mean concavity_mean concave.points_mean ⋯
# 1 0.11840         0.27760          0.3001         0.14710             ⋯
# 2 0.08474         0.07864          0.0869         0.07017             ⋯
# 3 0.10960         0.15990          0.1974         0.12790             ⋯
# 4 0.14250         0.28390          0.2414         0.10520             ⋯
# 5 0.10030         0.13280          0.1980         0.10430             ⋯
# ...

# %%
str(data_cancer)
# Out:
# 'data.frame':	569 obs. of  33 variables:
#  $ id                     : int  842302 842517 84300903 84348301 84358402 843786 844359 84458202 844981 84501001 ...
#  $ diagnosis              : chr  "M" "M" "M" "M" ...
#  $ radius_mean            : num  18 20.6 19.7 11.4 20.3 ...
#  $ texture_mean           : num  10.4 17.8 21.2 20.4 14.3 ...
#  $ perimeter_mean         : num  122.8 132.9 130 77.6 135.1 ...
#  $ area_mean              : num  1001 1326 1203 386 1297 ...
#  $ smoothness_mean        : num  0.1184 0.0847 0.1096 0.1425 0.1003 ...
#  $ compactness_mean       : num  0.2776 0.0786 0.1599 0.2839 0.1328 ...
#  $ concavity_mean         : num  0.3001 0.0869 0.1974 0.2414 0.198 ...
#  $ concave.points_mean    : num  0.1471 0.0702 0.1279 0.1052 0.1043 ...
#  $ symmetry_mean          : num  0.242 0.181 0.207 0.26 0.181 ...
#  $ fractal_dimension_mean : num  0.0787 0.0567 0.06 0.0974 0.0588 ...
#  $ radius_se              : num  1.095 0.543 0.746 0.496 0.757 ...
# ...

# %%
tail(data_cancer)
# Out:
#     id     diagnosis radius_mean texture_mean perimeter_mean area_mean
# 564 926125 M         20.92       25.09        143.00         1347.0
# 565 926424 M         21.56       22.39        142.00         1479.0
# 566 926682 M         20.13       28.25        131.20         1261.0
# 567 926954 M         16.60       28.08        108.30          858.1
# 568 927241 M         20.60       29.33        140.10         1265.0
# 569  92751 B          7.76       24.54         47.92          181.0
#     smoothness_mean compactness_mean concavity_mean concave.points_mean ⋯
# 564 0.10990         0.22360          0.31740        0.14740             ⋯
# 565 0.11100         0.11590          0.24390        0.13890             ⋯
# 566 0.09780         0.10340          0.14400        0.09791             ⋯
# 567 0.08455         0.10230          0.09251        0.05302             ⋯
# 568 0.11780         0.27700          0.35140        0.15200             ⋯
# ...

# %%
data_cancer$diagnosis <- as.integer(data_cancer$diagnosis)

# %%
head(data_cancer)
# Out:
#   id       diagnosis radius_mean texture_mean perimeter_mean area_mean
# 1   842302 1         17.99       10.38        122.80         1001.0
# 2   842517 1         20.57       17.77        132.90         1326.0
# 3 84300903 1         19.69       21.25        130.00         1203.0
# 4 84348301 1         11.42       20.38         77.58          386.1
# 5 84358402 1         20.29       14.34        135.10         1297.0
# 6   843786 1         12.45       15.70         82.57          477.1
#   smoothness_mean compactness_mean concavity_mean concave.points_mean ⋯
# 1 0.11840         0.27760          0.3001         0.14710             ⋯
# 2 0.08474         0.07864          0.0869         0.07017             ⋯
# 3 0.10960         0.15990          0.1974         0.12790             ⋯
# 4 0.14250         0.28390          0.2414         0.10520             ⋯
# 5 0.10030         0.13280          0.1980         0.10430             ⋯
# ...

# %%
r <- cor(data_cancer)

# %%
r
# Out:
#                         id            diagnosis    radius_mean  texture_mean
# id                       1.0000000000 -0.039768510  0.074626470  0.099769891
# diagnosis               -0.0397685096  1.000000000 -0.730028511 -0.415185300
# radius_mean              0.0746264697 -0.730028511  1.000000000  0.323781891
# texture_mean             0.0997698912 -0.415185300  0.323781891  1.000000000
# perimeter_mean           0.0731594119 -0.742635530  0.997855281  0.329533059
# area_mean                0.0968928233 -0.708983837  0.987357170  0.321085696
# smoothness_mean         -0.0129681975 -0.358559965  0.170581187 -0.023388516
# compactness_mean         0.0000957011 -0.596533678  0.506123578  0.236702222
# concavity_mean           0.0500799532 -0.696359707  0.676763550  0.302417828
# concave.points_mean      0.0441580956 -0.776613840  0.822528522  0.293464051
# symmetry_mean           -0.0221140609 -0.330498554  0.147741242  0.071400980
# ...

# %%
install.packages("ggcorrplot")
library(ggcorrplot)

ggcorrplot(r)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘plyr’, ‘reshape2’
#
#
# Loading required package: ggplot2
# plot without title
